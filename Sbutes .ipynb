# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import plotly.plotly as ply
import plotly.graph_objs as go
from datetime import datetime
import numpy as np

# %%
#mol_2016 = pd.read_csv(r'C:\Users\alejandro.m.gizzi\Documents\Mine\Mol 2016.csv', sep=";")
mol_2017 = pd.read_csv(r'C:\Users\alejandro.m.gizzi\Documents\Mine\Mol 2017.csv', sep=";")
mol_2018 = pd.read_csv(r'C:\Users\alejandro.m.gizzi\Documents\Mine\Mol 2018.csv', sep=",")

# %%
#DF formatting and consolidation

pd.set_option('float_format', '{:f}'.format)
mol_2017 = mol_2017.drop(['ID'],axis=1)
mol_2018.columns = mol_2017.columns


#mol_2016['FECHA'] = pd.to_datetime(pd.Series(mol_2016['FECHA']), format="%d/%m/%Y")
mol_2017['FECHA'] = pd.to_datetime(pd.Series(mol_2017['FECHA']), format="%d/%m/%Y")
mol_2018['FECHA'] = pd.to_datetime(mol_2018['FECHA'])


#mol_2016['Month'] = pd.DatetimeIndex(mol_2016['FECHA']).month
#mol_2016['Year'] = pd.DatetimeIndex(mol_2016['FECHA']).year

mol_2017['Month'] = pd.DatetimeIndex(mol_2017['FECHA']).month
mol_2017['Year'] = pd.DatetimeIndex(mol_2017['FECHA']).year

mol_2018['Month'] = pd.DatetimeIndex(mol_2018['FECHA']).month
mol_2018['Year'] = pd.DatetimeIndex(mol_2018['FECHA']).year


ALLMOL = mol_2017.append(mol_2018, ignore_index=False)
#ALLMOL = ALLMOL.append(mol_2018, ignore_index=False)

#drops unnecesarry columns
ALLMOL.drop(['PAX_PAGOS'],axis=1,inplace=True)
ALLMOL.drop(['PAX_PASES_PAGOS'],axis=1,inplace=True)
ALLMOL.drop(['PAX_FRANQ'],axis=1,inplace=True)

#drops total with 0
ALLMOL= ALLMOL[ALLMOL['TOTAL'] != 0]

#drops na rows
ALLMOL.dropna(how='any', inplace=True)

#replace all missing values in total
#https://towardsdatascience.com/data-cleaning-with-python-and-pandas-detecting-missing-values-3e9c6ebcf78b
#ALLMOL.isnull().values.any()
ALLMOL['TOTAL'].fillna(0, inplace=True)

#drops taller/pruebas
ALLMOL= ALLMOL[ALLMOL['LINEA'] !='TALLER/PRUEBAS']

#drops useless molinetes 
ALLMOL= ALLMOL[ALLMOL['MOLINETE'] !='LINEA_A_SNZPEÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x91A_N_TURN02']
ALLMOL= ALLMOL[ALLMOL['MOLINETE'] !='LINEA_A_SNZPEÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x91A_S_TURN03']
ALLMOL= ALLMOL[ALLMOL['MOLINETE'] !='LINEA_A_SNZPEÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x91A_N_TURN01']
ALLMOL= ALLMOL[ALLMOL['MOLINETE'] !='LINEA_A_SNZPEÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x91A_S_TURN01']
ALLMOL= ALLMOL[ALLMOL['MOLINETE'] !='LINEA_A_SNZPEÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x91A_S_TURN02']
ALLMOL= ALLMOL[ALLMOL['MOLINETE'] !='BONIFACIO_TUR02']

#creates column with weekday name
#https://docs.python.org/3/library/datetime.html#strftime-strptime-behavior
#https://webcache.googleusercontent.com/search?q=cache:GywFzb4hhjsJ:https://stackoverflow.com/questions/8380389/how-to-get-day-name-in-datetime-in-python+&cd=1&hl=es-419&ct=clnk&gl=ar
ALLMOL['WeekDay'] = ALLMOL['FECHA'].dt.strftime("%A")


#standardize the LINEA column
ALLMOL[ALLMOL['LINEA'] =='LineaA'] = "LINEA_A"
ALLMOL[ALLMOL['LINEA'] =='LineaB'] = "LINEA_B"
ALLMOL[ALLMOL['LINEA'] =='LineaC'] = "LINEA_C"
ALLMOL[ALLMOL['LINEA'] =='LineaD'] = "LINEA_D"
ALLMOL[ALLMOL['LINEA'] =='LineaE'] = "LINEA_E"
ALLMOL[ALLMOL['LINEA'] =='LineaH'] = "LINEA_H"

#drop this from total column
ALLMOL= ALLMOL[ALLMOL['TOTAL'] !='LINEA_A']
ALLMOL= ALLMOL[ALLMOL['TOTAL'] !='LINEA_B']
ALLMOL= ALLMOL[ALLMOL['TOTAL'] !='LINEA_C']
ALLMOL= ALLMOL[ALLMOL['TOTAL'] !='LINEA_D']
ALLMOL= ALLMOL[ALLMOL['TOTAL'] !='LINEA_E']
ALLMOL= ALLMOL[ALLMOL['TOTAL'] !='LINEA_H']

#convert total to float
#https://webcache.googleusercontent.com/search?q=cache:KKdR0CYFR6QJ:https://stackoverflow.com/questions/15891038/change-data-type-of-columns-in-pandas/45026465+&cd=2&hl=es-419&ct=clnk&gl=ar
ALLMOL["TOTAL"] = pd.to_numeric(ALLMOL["TOTAL"])
#ALLMOL.dtypes


ALLMOL.to_csv("ALLMOL.csv", sep=';', encoding='utf-8')

# %%
#-------------------------trash-----------------------------------------------------|
#mol_2018.rename(columns={'fecha': 'FECHA'}, inplace=True)
#mol_2018.rename(columns={'total': 'TOTAL'}, inplace=True)
#mol_2018['fecha'] = pd.to_datetime(pd.Series(mol_2018['fecha']), format="%d/%m/%Y")|
#mol_2016['Mes'] = mol_2016['PERIODO']                                              |
#mol_2016['Mes'] = mol_2016['FECHA'].Month                                          |
#mol_2016['Mes'] = mol_2016['FECHA'].Year                                           |
#df['Mes'] = df['Mes'].str[-2:]                                                     |
#mol_2016_Totpagos = mol_2016.set_index('Month', inplace=False)                     |
#mol_2016_Totpagos = mol_2016.groupby(level=0)['TOTAL'].sum()                       |
#mol_2016_Totpagos                                                                  |
#-------------------------trash-----------------------------------------------------|


import gc
#gc.collect()

# %%
#DF totals by period
TotPag16 = mol_2016
TotPag16.set_index(["Year","Month"], inplace=True)
TotPag16 = TotPag16.sum(level=["Year","Month"])
mol_2016 = mol_2016.reset_index()

TotPag17 = mol_2017
TotPag17.set_index(["Year","Month"], inplace=True)
TotPag17 = TotPag17.sum(level=["Year","Month"])
mol_2017 = mol_2017.reset_index()

TotPag18 = mol_2018
TotPag18.set_index(["Year","Month"], inplace=True)
TotPag18 = TotPag18.sum(level=["Year","Month"])
mol_2018 = mol_2018.reset_index()

TotPaghist = TotPag16.append(TotPag17, ignore_index=False)
TotPaghist = TotPaghist.append(TotPag18, ignore_index=False)
TotPaghist = TotPaghist.drop(['PERIODO','PAX_PAGOS','PAX_PASES_PAGOS','PAX_FRANQ'],axis=1)

# %%
#line plot
#fig, ax = plt.subplots(figsize=(50,5))
#ax.plot(TotPaghist['Year'].map(str) + " " + TotPaghist['Month'].map(str), TotPaghist['TOTAL'], color='r')
#plt.show()


#Scatter plot
#fig, ax = plt.subplots(figsize=(50,5))
#ax.scatter(TotPaghist['Year'].map(str) + " " + TotPaghist['Month'].map(str), TotPaghist['TOTAL'], edgecolors='r')
#plt.show()


#plot
#fig, ax = plt.subplots(figsize=(50,5))
#ax.plot_date(ALLMOL['FECHA'], ALLMOL['TOTAL'], color='r')
#plt.show()


#interactive plot kills ram
#data = [go.Scatter(x=ALLMOL['FECHA'], y=ALLMOL['TOTAL'])]

#ply.iplot(data, filename = 'time-series-simple')

# %%
#mean and std by weekday

#https://webcache.googleusercontent.com/search?q=cache:iBCzF1giI64J:https://stackoverflow.com/questions/30482071/how-to-calculate-mean-values-grouped-on-another-column-in-pandas+&cd=1&hl=es-419&ct=clnk&gl=ar
WeekdayTotalmean = ALLMOL.groupby('WeekDay', as_index=False)['TOTAL'].mean()

#https://webcache.googleusercontent.com/search?q=cache:cHr8bCdXsYUJ:https://stackoverflow.com/questions/20350863/pandas-dataframe-groupby-std+&cd=1&hl=es-419&ct=clnk&gl=ar
WeekdayTotalstd = ALLMOL.groupby('WeekDay')['TOTAL'].std()

#https://webcache.googleusercontent.com/search?q=cache:oEh9T7lHF9EJ:https://stackoverflow.com/questions/37968785/merging-two-dataframes+&cd=1&hl=es-419&ct=clnk&gl=ar
WDTmeanvar = pd.merge(WeekdayTotalmean,WeekdayTotalstd.to_frame(),how='left',on=['WeekDay'])
WDTmeanvar.rename(columns={'TOTAL_x': 'MEAN','TOTAL_y': 'STD'}, inplace=True)
WDTmeanvar['+/- Dif'] =  abs(WDTmeanvar['MEAN'] - WDTmeanvar['STD']) 
WDTmeanvar

# %%
#mean and std by Molinete
Molmean = ALLMOL.groupby('MOLINETE', as_index=False)['TOTAL'].mean()
Molstd = ALLMOL.groupby('MOLINETE')['TOTAL'].std()

MOLmeanvar = pd.merge(Molmean,Molstd.to_frame(),how='left',on=['MOLINETE'])
MOLmeanvar.rename(columns={'TOTAL_x': 'MEAN','TOTAL_y': 'STD'}, inplace=True)
MOLmeanvar['+/- Dif'] =  abs(MOLmeanvar['MEAN'] - MOLmeanvar['STD']) 
MOLmeanvar

# %%
#mean and std by Molinete, weekday and starting time
BMOLmean= ALLMOL.groupby(['MOLINETE','WeekDay','DESDE'], as_index=False)['TOTAL'].mean()
BMOLstd = ALLMOL.groupby(['MOLINETE','WeekDay','DESDE'])['TOTAL'].std()

BMMOLmeanvar = pd.merge(BMOLmean,BMOLstd.to_frame(),how='left',on=['MOLINETE'])
BMMOLmeanvar.rename(columns={'TOTAL_x': 'MEAN','TOTAL_y': 'STD'}, inplace=True)
BMMOLmeanvar['+/- Dif'] =  abs(BMMOLmeanvar['MEAN'] - BMMOLmeanvar['STD']) 
BMMOLmeanvar


#count                     148427918
#unique                          586
#top       LINEA_A_CONGRESO_S_TURN03
#freq                         277729

# %%
#get linea a molinetes 
match =  [ 'LINEA_A', 'TURN01']
MOLmeanvar[MOLmeanvar['MOLINETE'].apply(lambda x: True if all(s in x for s in match) else False)]


#ALLMOL.drop('Unnamed: 0',axis=1,inplace=True)
#ALLMOL.drop('Unnamed: 0.1',axis=1,inplace=True)
#ALLMOL[ALLMOL['MOLINETE'].apply(lambda x: "TURN01" in x)]

#como un filtro de excel
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html
ALLMOL[(ALLMOL['LINEA']=='LINEA_A') & (ALLMOL['ESTACION']=='PERU') & (ALLMOL['WeekDay']=='Sunday')  & (ALLMOL['FECHA']=='2017-01-01')].sort_values(by=['FECHA','DESDE'])

ALLMOL[(ALLMOL['LINEA']=='LINEA_A') & (ALLMOL['ESTACION']=='PERU') & (ALLMOL['WeekDay']=='Sunday')  & (ALLMOL['FECHA']=='2017-01-01')].MOLINETE.unique()

# %%
#para cargar
#ALLMOL = pd.read_csv(r'C:\Users\alejandro.m.gizzi\Documents\Mine\ALLMOL.csv', sep=";")
ALLMOL.drop('Unnamed: 0',axis=1,inplace=True)
#ALLMOL.head()

# %%
#para guardar
ALLMOL.to_csv("ALLMOL.csv", sep=';', encoding='utf-8')

# %%
#limpiar memoria
gc.collect()
#%reset
# Out:
# 57

# %%
#BMMOLA = BMMOLmeanvar[BMMOLmeanvar['MOLINETE'].apply(lambda x: "LINEA_A" in x)]

# %%
LIN_A=ALLMOL[ALLMOL['LINEA']=='LINEA_A']

# %%
#
#LIN_A.drop('Unnamed: 0',axis=1,inplace=True)
ALLMOL=""
gc.collect()
BMOLmean= LIN_A.groupby(['WeekDay','DESDE','MOLINETE'], as_index=False)['TOTAL'].mean()
BMOLstd = LIN_A.groupby(['WeekDay','DESDE','MOLINETE'])['TOTAL'].std()

BMMOLmeanvar = pd.merge(BMOLmean,BMOLstd.to_frame(),how='left',on=['MOLINETE'])

BMOLmean=""
BMOLstd=""
gc.collect()
BMMOLmeanvar.rename(columns={'TOTAL_x': 'MEAN','TOTAL_y': 'STD'}, inplace=True)
BMMOLmeanvar['+/- Dif'] =  abs(BMMOLmeanvar['MEAN'] - BMMOLmeanvar['STD']) 

BMMOLmeanvar.dropna()
BMMOLmeanvar=BMMOLmeanvar[BMMOLmeanvar.STD != 0]
BMMOLmeanvar=BMMOLmeanvar[BMMOLmeanvar.MOLINETE != 'LINEA_A_ACOYTE_N_ASC01']


#remover duplicados
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html
BMMOLmeanvar.drop_duplicates(subset=['WeekDay','DESDE','MOLINETE'],inplace=True)
BMMOLmeanvar.dropna(inplace=True)
BMMOLmeanvar.to_csv("linea_A_mean_std.csv", sep=';', encoding='utf-8')
BMMOLmeanvar.info()
BMMOLmeanvar


#BMMOLmeanvar['MOLINETE'].unique()
#BMMOLmeanvar[BMMOLmeanvar.MEAN==0]
#LIN_A.info()
#BMMOLmeanvar[BMMOLmeanvar['MOLINETE']=='LINEA_A_PERU_S_TURN01']
#BMMOLmeanvar.loc[33040]
# Out:
#             WeekDay     DESDE                 MOLINETE      MEAN        STD  \
# 0            Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   0.756439
# 1            Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   1.079021
# 2            Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   1.471846
# 3            Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   1.026722
# 4            Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   1.808319
# 5            Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   2.578176
# 6            Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   3.601632
# 7            Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   6.192809
# 8            Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   9.003192
# 9            Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179  12.474076
# 10           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179  11.281194
# 11           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179  12.247828
# 12           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179  17.388457
# 13           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179  19.425829
# 14           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179  19.008460
# 15           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179  18.850439
# 16           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179  19.256724
# 17           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179  18.556642
# 18           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179  16.650576
# 19           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179  13.888436
# 20           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179  11.443269
# 21           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   9.994331
# 22           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   8.684605
# 23           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   8.658155
# 24           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   7.652533
# 25           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   8.135659
# 26           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   8.787152
# 27           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   8.245249
# 28           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   8.715066
# 29           Friday  05:00:00  LINEA_A_ACOYTE_N_TURN01  1.487179   8.984499
# ...             ...       ...                      ...       ...        ...
# 32346785  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  32.455906
# 32346786  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  34.358287
# 32346787  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  48.607369
# 32346788  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  51.444882
# 32346789  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  50.966834
# 32346790  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  44.827675
# 32346791  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  58.672321
# 32346792  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  58.166886
# 32346793  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  43.323627
# 32346794  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  32.196638
# 32346795  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  26.605631
# 32346796  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  23.900837
# 32346797  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  16.947991
# 32346798  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  13.660214
# 32346799  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  14.552086
# 32346800  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  15.690840
# 32346801  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000  12.413416
# 32346802  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000   9.240338
# 32346803  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000   8.437897
# 32346804  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000   8.719882
# 32346805  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000   7.672681
# 32346806  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000   7.063258
# 32346807  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000   7.069650
# 32346808  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000   4.644370
# 32346809  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000   3.013175
# 32346810  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000   2.926714
# 32346811  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000   2.044949
# 32346812  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000   3.499608
# 32346813  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000        NaN
# 32346814  Wednesday  23:45:00   LINEA_A_PMAYO_E_TURN04  3.000000        NaN
#
#             +/- Dif
# 0          0.730741
# 1          0.408159
# 2          0.015334
# 3          0.460458
# 4          0.321139
# 5          1.090996
# 6          2.114452
# 7          4.705629
# 8          7.516013
# 9         10.986896
# 10         9.794015
# 11        10.760648
# 12        15.901277
# 13        17.938650
# 14        17.521281
# 15        17.363259
# 16        17.769545
# 17        17.069462
# 18        15.163396
# 19        12.401256
# 20         9.956090
# 21         8.507152
# 22         7.197426
# 23         7.170975
# 24         6.165353
# 25         6.648479
# 26         7.299972
# 27         6.758069
# 28         7.227887
# 29         7.497320
# ...             ...
# 32346785  29.455906
# 32346786  31.358287
# 32346787  45.607369
# 32346788  48.444882
# 32346789  47.966834
# 32346790  41.827675
# 32346791  55.672321
# 32346792  55.166886
# 32346793  40.323627
# 32346794  29.196638
# 32346795  23.605631
# 32346796  20.900837
# 32346797  13.947991
# 32346798  10.660214
# 32346799  11.552086
# 32346800  12.690840
# 32346801   9.413416
# 32346802   6.240338
# 32346803   5.437897
# 32346804   5.719882
# 32346805   4.672681
# 32346806   4.063258
# 32346807   4.069650
# 32346808   1.644370
# 32346809   0.013175
# 32346810   0.073286
# 32346811   0.955051
# 32346812   0.499608
# 32346813        NaN
# 32346814        NaN
#
# [31696586 rows x 6 columns]

# %%
Aonly = pd.merge(LIN_A,BMMOLmeanvar,how='left',on=['MOLINETE','WeekDay','DESDE'])
Aonly.to_csv("LineaAcompletalimpia.csv", sep=';', encoding='utf-8')


#https://webcache.googleusercontent.com/search?q=cache:T2k9K7vxn3sJ:https://stackoverflow.com/questions/27474921/compare-two-columns-using-pandas+&cd=1&hl=es-419&ct=clnk&gl=ar
#Aonly['Normal'] = np.where(Aonly['TOTAL'] < (Aonly['MEAN'] - Aonly['STD']), False, True)

# %%
#PARA PREDECIR
#falta agregarle los tweets del otro dataset para cruzar con los dias que hubo problemas
#cuando tengamos eso ahi hay que empezar a entrenarlo para que tome como variables la media y el desvio estandar
#para predecir si la cantidad de personas es normal o no, y en ese caso ver dependiendo del dia y el horario
#si puede ser una falla, un paro o lo que sea. 
#deberiamos buscar alguna otra variable que pueda demostrar un uso no usual del molinete


#PARA IDENTIFICAR
#deberiamos agrupar bien los momentos en que no estuvo andando bien y armar un buen grafico
# Out:
# WeekDay                    Friday
# DESDE                    05:00:00
# MOLINETE    LINEA_A_PERU_S_TURN01
# MEAN                      1.39286
# STD                       0.62889
# +/- Dif                  0.763967
# Name: 33040, dtype: object

# %%
# Out:
#          PERIODO       FECHA     DESDE     HASTA    LINEA  \
# 0         201701  2017-01-01  08:00:00  08:15:00  LINEA_A
# 1         201701  2017-01-01  08:15:00  08:30:00  LINEA_A
# 2         201701  2017-01-01  08:15:00  08:30:00  LINEA_A
# 3         201701  2017-01-01  08:30:00  08:45:00  LINEA_A
# 4         201701  2017-01-01  08:30:00  08:45:00  LINEA_A
# 5         201701  2017-01-01  09:00:00  09:15:00  LINEA_A
# 6         201701  2017-01-01  09:15:00  09:30:00  LINEA_A
# 7         201701  2017-01-01  09:15:00  09:30:00  LINEA_A
# 8         201701  2017-01-01  09:30:00  09:45:00  LINEA_A
# 9         201701  2017-01-01  09:30:00  09:45:00  LINEA_A
# 10        201701  2017-01-01  09:45:00  10:00:00  LINEA_A
# 11        201701  2017-01-01  09:45:00  10:00:00  LINEA_A
# 12        201701  2017-01-01  10:00:00  10:15:00  LINEA_A
# 13        201701  2017-01-01  10:00:00  10:15:00  LINEA_A
# 15        201701  2017-01-01  10:00:00  10:15:00  LINEA_A
# 16        201701  2017-01-01  10:15:00  10:30:00  LINEA_A
# 17        201701  2017-01-01  10:15:00  10:30:00  LINEA_A
# 18        201701  2017-01-01  10:15:00  10:30:00  LINEA_A
# 19        201701  2017-01-01  10:15:00  10:30:00  LINEA_A
# 20        201701  2017-01-01  10:30:00  10:45:00  LINEA_A
# 21        201701  2017-01-01  10:30:00  10:45:00  LINEA_A
# 22        201701  2017-01-01  10:45:00  11:00:00  LINEA_A
# 23        201701  2017-01-01  11:00:00  11:15:00  LINEA_A
# 24        201701  2017-01-01  11:15:00  11:30:00  LINEA_A
# 25        201701  2017-01-01  11:30:00  11:45:00  LINEA_A
# 26        201701  2017-01-01  11:45:00  12:00:00  LINEA_A
# 27        201701  2017-01-01  11:45:00  12:00:00  LINEA_A
# 28        201701  2017-01-01  11:45:00  12:00:00  LINEA_A
# 29        201701  2017-01-01  12:00:00  12:15:00  LINEA_A
# 30        201701  2017-01-01  12:00:00  12:15:00  LINEA_A
# ...          ...         ...       ...       ...      ...
# 3212185   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212186   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212187   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212188   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212189   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212190   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212191   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212192   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212193   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212194   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212195   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212196   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212197   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212198   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212199   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212200   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212201   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212202   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212203   201803  2018-03-31  23:30:00  23:45:00  LINEA_A
# 3212204   201803  2018-03-31  23:45:00  00:00:00  LINEA_A
# 3212205   201803  2018-03-31  23:45:00  00:00:00  LINEA_A
# 3212206   201803  2018-03-31  23:45:00  00:00:00  LINEA_A
# 3212207   201803  2018-03-31  23:45:00  00:00:00  LINEA_A
# 3212208   201803  2018-03-31  23:45:00  00:00:00  LINEA_A
# 3212209   201803  2018-03-31  23:45:00  00:00:00  LINEA_A
# 3212210   201803  2018-03-31  23:45:00  00:00:00  LINEA_A
# 3212211   201803  2018-03-31  23:45:00  00:00:00  LINEA_A
# 3212212   201803  2018-03-31  23:45:00  00:00:00  LINEA_A
# 3212214   201803  2018-03-31  23:45:00  00:00:00  LINEA_A
# 3212215   201803  2018-03-31  23:45:00  00:00:00  LINEA_A
#
#                                 MOLINETE        ESTACION  TOTAL  Month  Year  \
# 0                  LINEA_A_PERU_S_TURN01            PERU    2.0      1  2017
# 1                  LINEA_A_PERU_S_TURN01            PERU    3.0      1  2017
# 2                  LINEA_A_PERU_S_TURN02            PERU    2.0      1  2017
# 3                  LINEA_A_PERU_S_TURN02            PERU    2.0      1  2017
# 4                  LINEA_A_PERU_S_TURN03            PERU    1.0      1  2017
# 5                  LINEA_A_PERU_S_TURN02            PERU    1.0      1  2017
# 6                  LINEA_A_PERU_S_TURN01            PERU    1.0      1  2017
# 7                  LINEA_A_PERU_S_TURN02            PERU    1.0      1  2017
# 8                  LINEA_A_PERU_S_TURN02            PERU    2.0      1  2017
# 9                  LINEA_A_PERU_S_TURN01            PERU    1.0      1  2017
# 10                 LINEA_A_PERU_S_TURN03            PERU    1.0      1  2017
# 11                 LINEA_A_PERU_S_TURN02            PERU    4.0      1  2017
# 12                 LINEA_A_PERU_S_TURN04            PERU    2.0      1  2017
# 13                 LINEA_A_PERU_S_TURN03            PERU    1.0      1  2017
# 15                 LINEA_A_PERU_S_TURN01            PERU    1.0      1  2017
# 16                 LINEA_A_PERU_S_TURN03            PERU    3.0      1  2017
# 17                 LINEA_A_PERU_S_TURN04            PERU    2.0      1  2017
# 18                 LINEA_A_PERU_S_TURN02            PERU    1.0      1  2017
# 19                 LINEA_A_PERU_S_TURN01            PERU    4.0      1  2017
# 20                 LINEA_A_PERU_S_TURN01            PERU    4.0      1  2017
# 21                 LINEA_A_PERU_S_TURN03            PERU    2.0      1  2017
# 22                 LINEA_A_PERU_S_TURN01            PERU    4.0      1  2017
# 23                 LINEA_A_PERU_N_TURN01            PERU    1.0      1  2017
# 24                 LINEA_A_PERU_S_TURN01            PERU    2.0      1  2017
# 25                 LINEA_A_PERU_S_TURN03            PERU    1.0      1  2017
# 26                 LINEA_A_PERU_S_TURN01            PERU    1.0      1  2017
# 27                 LINEA_A_PERU_S_TURN02            PERU    1.0      1  2017
# 28                 LINEA_A_PERU_S_TURN04            PERU    3.0      1  2017
# 29                 LINEA_A_PERU_S_TURN01            PERU    3.0      1  2017
# 30                 LINEA_A_PERU_S_TURN02            PERU    1.0      1  2017
# ...                                  ...             ...    ...    ...   ...
# 3212185             LINEA_A_PASCO_TURN02           PASCO    1.0      3  2018
# 3212186            LINEA_A_PERU_N_TURN01            PERU    1.0      3  2018
# 3212187         LINEA_A_PIEDRAS_S_TURN01         PIEDRAS    4.0      3  2018
# 3212188           LINEA_A_PMAYO_E_TURN02   PLAZA DE MAYO    3.0      3  2018
# 3212189         LINEA_A_CBARROS_S_TURN01   CASTRO BARROS    2.0      3  2018
# 3212190           LINEA_A_LORIA_N_TURN03           LORIA    2.0      3  2018
# 3212191        LINEA_A_MISERERE_S_TURN01  PLAZA MISERERE    2.0      3  2018
# 3212192        LINEA_A_MISERERE_S_TURN03  PLAZA MISERERE    2.0      3  2018
# 3212193  LINEA_A_SANPEDRITO_OESTE_TURN01     SAN PEDRITO    1.0      3  2018
# 3212194            LINEA_A_LIMA_S_TURN02            LIMA    6.0      3  2018
# 3212195   LINEA_A_MISERERE_Q_HALL_TURN04  PLAZA MISERERE    1.0      3  2018
# 3212196            LINEA_A_PERU_S_TURN02            PERU    4.0      3  2018
# 3212197        LINEA_A_RJANEIRO_N_TURN02  RIO DE JANEIRO    4.0      3  2018
# 3212198         LINEA_A_CBARROS_S_TURN02   CASTRO BARROS    1.0      3  2018
# 3212199            LINEA_A_LIMA_S_TURN03            LIMA    4.0      3  2018
# 3212200            LINEA_A_PERU_S_TURN01            PERU    2.0      3  2018
# 3212201           LINEA_A_PMAYO_E_TURN01   PLAZA DE MAYO    2.0      3  2018
# 3212202        LINEA_A_CONGRESO_S_TURN03        CONGRESO    6.0      3  2018
# 3212203   LINEA_A_MISERERE_Q_HALL_TURN05  PLAZA MISERERE    2.0      3  2018
# 3212204            LINEA_A_PERU_S_TURN05            PERU    1.0      3  2018
# 3212205        LINEA_A_CONGRESO_S_TURN03        CONGRESO    1.0      3  2018
# 3212206            LINEA_A_LIMA_S_TURN01            LIMA    1.0      3  2018
# 3212207         LINEA_A_PIEDRAS_S_TURN01         PIEDRAS    1.0      3  2018
# 3212208        LINEA_A_RJANEIRO_S_TURN02  RIO DE JANEIRO    2.0      3  2018
# 3212209        LINEA_A_CARABOBO_O_TURN04        CARABOBO    1.0      3  2018
# 3212210        LINEA_A_CONGRESO_S_TURN01        CONGRESO    2.0      3  2018
# 3212211        LINEA_A_CONGRESO_S_TURN02        CONGRESO    3.0      3  2018
# 3212212           LINEA_A_PMAYO_E_TURN02   PLAZA DE MAYO    1.0      3  2018
# 3212214            LINEA_A_LIMA_S_TURN02            LIMA    7.0      3  2018
# 3212215        LINEA_A_MISERERE_S_TURN03  PLAZA MISERERE    1.0      3  2018
#
#           WeekDay      MEAN       STD   +/- Dif  Normal
# 0          Sunday  3.314815  0.628890  2.685925   False
# 1          Sunday  2.927273  0.628890  2.298383    True
# 2          Sunday  3.072727  0.535303  2.537424   False
# 3          Sunday  2.944444  0.535303  2.409141   False
# 4          Sunday  2.111111  0.333333  1.777778   False
# 5          Sunday  2.945455  0.535303  2.410151   False
# 6          Sunday  2.981481  0.628890  2.352591   False
# 7          Sunday  3.557692  0.535303  3.022389   False
# 8          Sunday  3.894737  0.535303  3.359433   False
# 9          Sunday  3.160000  0.628890  2.531110   False
# 10         Sunday  2.729167  0.333333  2.395833   False
# 11         Sunday  4.074074  0.535303  3.538771    True
# 12         Sunday  1.964286  0.500000  1.464286    True
# 13         Sunday  3.078431  0.333333  2.745098   False
# 15         Sunday  2.980000  0.628890  2.351110   False
# 16         Sunday  3.660000  0.333333  3.326667   False
# 17         Sunday  1.793103  0.500000  1.293103    True
# 18         Sunday  4.423729  0.535303  3.888425   False
# 19         Sunday  3.222222  0.628890  2.593332    True
# 20         Sunday  3.803571  0.628890  3.174681    True
# 21         Sunday  4.345455  0.333333  4.012121   False
# 22         Sunday  4.372881  0.628890  3.743991    True
# 23         Sunday  2.083333  0.332106  1.751228   False
# 24         Sunday  4.857143  0.628890  4.228253   False
# 25         Sunday  4.745455  0.333333  4.412121   False
# 26         Sunday  4.810345  0.628890  4.181455   False
# 27         Sunday  6.984375  0.535303  6.449072   False
# 28         Sunday  2.911765  0.500000  2.411765    True
# 29         Sunday  6.550000  0.628890  5.921110   False
# 30         Sunday  7.656250  0.535303  7.120947   False
# ...           ...       ...       ...       ...     ...
# 3212185  Saturday  1.333333  0.452267  0.881066    True
# 3212186  Saturday  1.333333  0.332106  1.001228   False
# 3212187  Saturday  2.000000  0.410391  1.589609    True
# 3212188  Saturday  4.333333  0.854040  3.479293   False
# 3212189  Saturday  1.666667  0.646206  1.020460    True
# 3212190  Saturday  2.000000  1.058281  0.941719    True
# 3212191  Saturday  1.625000  0.607685  1.017315    True
# 3212192  Saturday  2.666667  0.985633  1.681034    True
# 3212193  Saturday  1.000000  1.731883  0.731883    True
# 3212194  Saturday  2.909091  0.768533  2.140558    True
# 3212195  Saturday  1.666667  1.375672  0.290995    True
# 3212196  Saturday  3.500000  0.535303  2.964697    True
# 3212197  Saturday  2.000000  0.477567  1.522433    True
# 3212198  Saturday  1.000000  0.440959  0.559041    True
# 3212199  Saturday  2.909091  0.622171  2.286920    True
# 3212200  Saturday  1.333333  0.628890  0.704443    True
# 3212201  Saturday  2.250000  1.567792  0.682208    True
# 3212202  Saturday  6.928571  1.500406  5.428165    True
# 3212203  Saturday  1.500000  1.431983  0.068017    True
# 3212204  Saturday  1.000000  0.650444  0.349556    True
# 3212205  Saturday  5.083333  1.500406  3.582927   False
# 3212206  Saturday  2.909091  0.980454  1.928637   False
# 3212207  Saturday  1.666667  0.410391  1.256275   False
# 3212208  Saturday  2.500000  0.462910  2.037090   False
# 3212209  Saturday  1.000000  0.503953  0.496047    True
# 3212210  Saturday  1.714286  0.377964  1.336321    True
# 3212211  Saturday  2.571429  0.548319  2.023110    True
# 3212212  Saturday  2.000000  0.854040  1.145960   False
# 3212214  Saturday  3.111111  0.768533  2.342578    True
# 3212215  Saturday  1.000000  0.985633  0.014367    True
#
# [3110112 rows x 15 columns]
