# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Rodri\Documents\GitHub\Final Project EANT\Final-Project-EANT\Notebooks\Areadytoplot.csv',sep = ';')
# Out:
# C:\Users\Rodri\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0  PERIODO       FECHA     DESDE     HASTA  \
# 0           0   201801  2018-01-01  08:00:00  08:15:00
# 1           1   201801  2018-01-01  08:00:00  08:15:00
# 2           2   201801  2018-01-01  08:00:00  08:15:00
# 3           3   201801  2018-01-01  08:00:00  08:15:00
# 4           4   201801  2018-01-01  08:00:00  08:15:00
#
#                    MOLINETE       ESTACION  TOTAL  Month  Year WeekDay_x  \
# 0  LINEA_A_CBARROS_S_TURN01  CASTRO BARROS    1.0      1  2018    Monday
# 1     LINEA_A_LIMA_S_TURN03           LIMA    4.0      1  2018    Monday
# 2      LINEA_A_PASCO_TURN01          PASCO    1.0      1  2018    Monday
# 3     LINEA_A_PERU_S_TURN01           PERU    4.0      1  2018    Monday
# 4   LINEA_A_PJUNTA_S_TURN02  PRIMERA JUNTA    2.0      1  2018    Monday
#
#         MEAN       STD    +/- Dif  Normal TEXT TIME Issuetype
# 0  16.984375  0.646206  16.338169   False  NaN  NaN    Normal
# 1  20.969231  0.622171  20.347060   False  NaN  NaN    Normal
# ...

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.set_index('MOLINETE', inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MOLINETE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-e474d5080d12> in <module>
#       5 #df_grafico
#       6
# ...

# %%
# FIltrado por un solo molinete segun fecha, desde y total
#df_filtrado1 = df.loc[['LINEA_A_CBARROS_S_TURN01'], ['FECHA','DESDE','TOTAL']]
#df_filtrado1.to_csv('df_filtrado_grafico.csv')
# Out:
#                                FECHA     DESDE  TOTAL
# MOLINETE
# LINEA_A_CBARROS_S_TURN01  2018-01-01  08:00:00    1.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  08:15:00    3.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  08:30:00    1.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  09:00:00    1.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  09:15:00    3.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  09:45:00    1.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  10:15:00    1.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  10:30:00    1.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  10:45:00    5.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  11:00:00    2.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  11:15:00    1.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  11:30:00    1.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  11:45:00    4.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  12:00:00    1.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  12:15:00    3.0
# LINEA_A_CBARROS_S_TURN01  2018-01-01  12:45:00    7.0
# ...

# %%
# Filtrado por todos los molinetes de todas las lineas de subte segun fecha, desde y total

#df_filtrado2 = df.loc[:, ['FECHA','DESDE','TOTAL']]
#df_filtrado2.to_csv('df_filtrado2_grafico.csv')
#df_filtrado2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 587384 entries, LINEA_A_CBARROS_S_TURN01 to FECHA
# Data columns (total 3 columns):
# FECHA    587384 non-null object
# DESDE    587384 non-null object
# TOTAL    587384 non-null object
# dtypes: object(3)
# memory usage: 37.9+ MB

# %%
# Filtrado por todos los molinetes de todas las lineas de subte segun desde y total solamente para el dia 2018-03-31

mascara = df['FECHA'] == '2018-03-31'
df_filtrado3 = df[mascara].loc[:,['ESTACION','DESDE','TOTAL']]
df_filtrado3_pivot = pd.pivot_table(df_filtrado3, index=['MOLINETE','ESTACION'], columns=['DESDE'], aggfunc=np.sum)
df_filtrado3_pivot.to_csv('df_filtrado3_pivot_grafico.csv')
